# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import plotnine as p9

# %%
df_raw = pd.read_csv("CustomerAcquisition.csv")

# %%
df_raw.head()
# Out:
#      food_category food_department food_family  store_sales(in millions)  \
# 0  Breakfast Foods    Frozen Foods        Food                      7.36
# 1  Breakfast Foods    Frozen Foods        Food                      5.52
# 2  Breakfast Foods    Frozen Foods        Food                      3.68
# 3  Breakfast Foods    Frozen Foods        Food                      3.68
# 4  Breakfast Foods    Frozen Foods        Food                      4.08
#
#    store_cost(in millions)  unit_sales(in millions)         promotion_name  \
# 0                   2.7232                      4.0           Bag Stuffers
# 1                   2.5944                      3.0  Cash Register Lottery
# 2                   1.3616                      2.0    High Roller Savings
# 3                   1.1776                      2.0  Cash Register Lottery
# 4                   1.4280                      3.0       Double Down Sale
#
#   sales_country marital_status gender  ...  grocery_sqft frozen_sqft  \
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60428 entries, 0 to 60427
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   food_category               60428 non-null  object
#  1   food_department             60428 non-null  object
#  2   food_family                 60428 non-null  object
#  3   store_sales(in millions)    60428 non-null  float64
#  4   store_cost(in millions)     60428 non-null  float64
#  5   unit_sales(in millions)     60428 non-null  float64
#  6   promotion_name              60428 non-null  object
#  7   sales_country               60428 non-null  object
#  8   marital_status              60428 non-null  object
#  9   gender                      60428 non-null  object
#  10  total_children              60428 non-null  float64
#  11  education                   60428 non-null  object
#  12  member_card                 60428 non-null  object
# ...

# %% [markdown]
# There are 17 categorical variables and 23 numerical variables in the chosen dataset.

# %% [markdown]
# ## Exploring Categorical Variables

# %% [markdown]
# <b>NOTE:</b> To get the exact value counts for each category of a variable, uncomment the first line of each cell.

# %%
#df_raw["food_category"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='food_category'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766190091111)>

# %%
#df_raw["food_department"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='food_department'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766189965553)>

# %%
#df_raw["food_family"].value_counts()
(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='food_family'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766189858756)>

# %%
#df_raw["promotion_name"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='promotion_name'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766121373913)>

# %%
#df_raw["sales_country"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='sales_country'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766190105573)>

# %%
#df_raw["marital_status"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='marital_status'))
    + p9.geom_bar(fill = "#33E9FF")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766121567410)>

# %%
#df_raw["gender"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='gender'))
    + p9.geom_bar(fill = "#33E9FF")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766121856253)>

# %%
#df_raw["education"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='education'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766121725410)>

# %%
#df_raw["member_card"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='member_card'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766142440171)>

# %%
#df_raw["occupation"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='occupation'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766190166519)>

# %%
#df_raw["houseowner"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='houseowner'))
    + p9.geom_bar(fill = "#33E9FF")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766142891204)>

# %%
#df_raw["avg. yearly_income"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='avg. yearly_income'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766155408538)>

# %%
#df_raw["brand_name"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='brand_name'))
    + p9.geom_bar(fill = "#FF6660", width = 0.80)
    + p9.theme_bw()
    + p9.theme(text = p9.element_text(size=6), axis_text_x = p9.element_text(angle=90),figure_size=(16, 8))
)
# Out:
# <ggplot: (8766157504488)>

# %%
#df_raw["store_type"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='store_type'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766155632372)>

# %%
#df_raw["store_city"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='store_city'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766155631532)>

# %%
#df_raw["store_state"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='store_state'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766144197355)>

# %%
#df_raw["media_type"].value_counts()

(p9.ggplot(data=df_raw,
           mapping=p9.aes(x='media_type'))
    + p9.geom_bar(fill = "#FF6660")
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (8766155376436)>

# %% [markdown]
# ## Exploring Numerical Variables

# %%
df_raw.describe()
# Out:
#        store_sales(in millions)  store_cost(in millions)  \
# count              60428.000000             60428.000000
# mean                   6.541031                 2.619460
# std                    3.463047                 1.453009
# min                    0.510000                 0.163200
# 25%                    3.810000                 1.500000
# 50%                    5.940000                 2.385600
# 75%                    8.670000                 3.484025
# max                   22.920000                 9.726500
#
#        unit_sales(in millions)  total_children  avg_cars_at home(approx)  \
# count             60428.000000    60428.000000              60428.000000
# mean                  3.093169        2.533875                  2.200271
# std                   0.827677        1.490165                  1.109644
# min                   1.000000        0.000000                  0.000000
# 25%                   3.000000        1.000000                  1.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=4)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=4)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)

df_raw.hist(bins=50, figsize=(20, 12), color='blue')
plt.show()

# %%
corr_matrix = df_raw.corr()
corr_matrix["cost"].sort_values(ascending=False)
# Out:
# cost                          1.000000
# avg_cars_at home(approx)      0.011658
# avg_cars_at home(approx).1    0.011658
# low_fat                       0.004207
# SRP                           0.002082
# net_weight                    0.001343
# gross_weight                  0.001281
# recyclable_package           -0.001720
# num_children_at_home         -0.002549
# units_per_case               -0.002776
# total_children               -0.003900
# store_cost(in millions)      -0.004162
# store_sales(in millions)     -0.004621
# unit_sales(in millions)      -0.015015
# grocery_sqft                 -0.025108
# store_sqft                   -0.039656
# meat_sqft                    -0.047962
# frozen_sqft                  -0.047971
# coffee_bar                   -0.060859
# florist                      -0.087340
# salad_bar                    -0.095596
# prepared_food                -0.095596
# video_store                  -0.111214
# Name: cost, dtype: float64

# %%
#drop duplicate column
df_raw = df_raw.drop(['avg_cars_at home(approx).1'], axis=1)
